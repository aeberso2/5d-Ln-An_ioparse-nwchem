# %%
import pandas as pd
from numpy import *
import matplotlib.pyplot as plt
import os, re, sys
top_dir = os.getcwd() 
print(top_dir)
# Out:
# C:\Users\aeberso2\OneDrive\Graduate School - MSU\Research - MSU\5d_things

# %%
# enthalpy information of each atom in the set
atoms_input = pd.read_excel('5d_experimental_vals.xlsx',sheetname='Atoms')
# experimental information for each compound in the set 
exp_vals= pd.read_excel('5d_experimental_vals.xlsx',sheetname='Cmpds_Mk2')
# computed dft energies for each compound in the set
dft_vals_ms = pd.read_excel('DFT_5d_enthal_mk_verify.xlsx',sheetname='Main')
dft_vals_so = pd.read_excel('DFT_5d_enthal_mk_verify.xlsx',sheetname='Main-SO')

# %%
HARTREE_to_KCAL = 627.509608
HARTREE_to_KJ  = 2625.5002

# needed to parse compound list for enthalpy calculation
# from the compound name, extracts a list of the constituent compounds
# then an array of how many times that element appears in the compound
# eg. WF6 returns ['W', 'F'] and [1, 6]
def create_atom_cmpd_list(usr_inp):
    int_set = []
    elem_list = []
    a = re.findall(r'[A-Z][a-z]*|\d+|\(|\)', usr_inp)
    for p in range(1,len(a)):
        if a[p-1].isalpha() and a[p].isalpha():
            if p == len(a)-1:
                int_set.append(1.0)
                int_set.append(1.0)
                elem_list.append(str(a[p-1]))
                elem_list.append(str(a[p]))
            else:
                int_set.append(1.0)
                elem_list.append(str(a[p-1]))               
                
        elif a[p-1].isalpha() and a[p].isdigit():
            int_set.append(float(a[p]))
            elem_list.append(str(a[p-1]))
    if a[-2].isdigit() and a[-1].isalpha():
        int_set.append(1)
        elem_list.append(str(a[-1]))     
        
    return array(elem_list), array(int_set)

# Color coating for Pandas tables in the jupyter notebook
# colors names are from the SVG standard
def enthal_color_quan(val):
    
    if val >= 0 and val < 6:
        color = 'steelblue'  
    elif (val) < 0 and (val) > -6:
        color = 'steelblue'   
    elif val >= 6 and val < 20:
        color = 'darkgoldenrod'  
    elif (val) <= -6 and (val) > -20:
        color = 'olive'           
    elif val >= 20 and val < 50:
        color = 'orangered'  
    elif (val) <= -20 and (val) > -50:
        color = 'chocolate'   
    elif val >= 50 and val < 400:
        color = 'crimson'  
    elif (val) <= -50 and (val) > -400:
        color = 'firebrick'             
    else:
        color = 'k'
    return 'color: {}'.format(color)

def dft_energy_error(atoms_input,exp_vals,dft_vals,check_consistency):
    # currently uses the JANAF experimental values, it takes all non blank entries 
    Janaf_exp_vals = exp_vals.loc['JANAF_exp','Au2':][exp_vals.loc['JANAF_exp','Au2':].notnull()]
    # a list of the calculated ZPE + H_inc
    Thermo_info = atoms_input.loc['H-H0':'DeltaHf298',:]
    # list of functional values for atoms then compounds 
    dft_atms = dft_vals.loc['SVWN':'B2PLYP','Hf':'I']
    dft_cmpds = dft_vals.loc['SVWN':'B2PLYP','Au2':]

    # temp array to hold values
    TEMP_HOLD = []
    # for each compound in the compound index
    for compd in dft_cmpds.axes[1][:]:
        # create the atom set adn integer list
        atom_set, int_list = create_atom_cmpd_list(compd)
        # start the sum for the first index multiply the number of times that atom appears in the cmpound
        # times the dft calculated atomic energy + the \ H_{inc} as (H(298) - H(0))
        # the minus 1 corrects the fact that Janaf lists the values as H(0) - H(298)
        sum_Eatom_Hinc = 0
        for i in range(0,len(atom_set)):
            sum_Eatom_Hinc += int_list[i]*(dft_atms.loc[:,atom_set[i]] 
                                           + (-1*Thermo_info.loc['H-H0', atom_set[i]]/HARTREE_to_KCAL)
                                          )

        # Add the calculated ZPVE and vibrational contributitons to enthalpy 
        Delta_H_sum = 0        
        for i in range(0,len(atom_set)):
            Delta_H_sum += (int_list[i]*Thermo_info.loc['DeltaHf298', atom_set[i]])/HARTREE_to_KCAL
        # compute total enthalpy 
        Total_enthalpy = (dft_cmpds.loc[:,compd] 
                          + dft_vals.loc['ThermC (Enthalpy)', compd] 
                          - sum_Eatom_Hinc 
                          + Delta_H_sum)*HARTREE_to_KCAL
        
        TEMP_HOLD.append(array(Total_enthalpy))

    Vals = pd.DataFrame(array(TEMP_HOLD), index=dft_cmpds.axes[1][:], columns=dft_cmpds.axes[0])

    # remove the elements for which there are no Janaf exp vals
    comparison_data = Vals.loc[Janaf_exp_vals.axes[0],:]
    signed_errors = comparison_data.copy()
    # compute difference from experiment, i.e. the signed error
    for compound in Janaf_exp_vals.axes[0]:
        signed_errors.loc[compound,:] = comparison_data.loc[compound,:] - Janaf_exp_vals[compound ] 
    # remove rows where all functionals have NaN values 
    # TPSS is chosen since optimizations were done with tpss, so if it has no value 
    # then no other functionals will have a value
    current_energy_vals = comparison_data[comparison_data.loc[:,'TPSS'].notnull()]
    current_error_vals = signed_errors[signed_errors.loc[:,'TPSS'].notnull()]

    # for determining problem molecules were functions give vastly different values amongst themselves
    if check_consistency == 'Yes':
        std_set = []
        for i in current_energy_vals.axes[0]:
            std_set.append(current_energy_vals.loc[i,:].std())
        consti_check = pd.Series(std_set,index=current_energy_vals.axes[0])

        state_is_consistent = consti_check[consti_check < 35]

        state_is_not_consistent = consti_check[consti_check >= 35]

        consistent_error_set = current_error_vals.loc[state_is_consistent.axes[0],:]

        inconsistent_error_set = current_error_vals.loc[state_is_not_consistent.axes[0],:]

        return current_error_vals, consistent_error_set, inconsistent_error_set, current_energy_vals
    else:
        return current_error_vals, current_energy_vals

# %%
# ,initial_vals_ms, initial_vals_so
error_recp, cons_error, incons_error, energy_recp = dft_energy_error(atoms_input,exp_vals,dft_vals_ms,'Yes')
error_so, energy_so = dft_energy_error(atoms_input,exp_vals,dft_vals_so,'No')

# %%
# energy_recp
# energies without SO correction

# %%
error_recp.style.applymap(enthal_color_quan)
# Out:
# <style  type="text/css" >
#     #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col0 {
#             color:  olive;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col1 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col2 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col3 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col4 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col5 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col6 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col7 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col8 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col9 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col10 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col11 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col12 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col13 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col14 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col15 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col16 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col17 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row0_col18 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col0 {
#             color:  olive;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col1 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col2 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col3 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col4 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col5 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col6 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col7 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col8 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col9 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col10 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col11 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col12 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col13 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col14 {
#             color:  steelblue;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col15 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col16 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col17 {
#             color:  k;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row1_col18 {
#             color:  k;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col0 {
#             color:  chocolate;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col1 {
#             color:  orangered;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col2 {
#             color:  orangered;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col3 {
#             color:  orangered;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col4 {
#             color:  orangered;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col5 {
#             color:  orangered;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col6 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col7 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col8 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col9 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col10 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col11 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col12 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col13 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col14 {
#             color:  orangered;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col15 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col16 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col17 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row2_col18 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col0 {
#             color:  orangered;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col1 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col2 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col3 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col4 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col5 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col6 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col7 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col8 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col9 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col10 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col11 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col12 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col13 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col14 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col15 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col16 {
#             color:  k;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col17 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row3_col18 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row4_col0 {
#             color:  darkgoldenrod;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row4_col1 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row4_col2 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row4_col3 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row4_col4 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row4_col5 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row4_col6 {
#             color:  crimson;
#         }    #T_dbd670ca_93dd_11e7_ba46_00059a3c7a00row4_col7 {
#             color:  crimson;

# %%
mCmpds = ['HfCl4','Au2','WCl4','HgCl2','TaCl5','WF6']

Mfunc = ['SVWN', 'BP86', 'BLYP', 'PW91', 'PBE', 'TPSS', 'M06-L', 'B3P86',
       'X3LYP', 'B97-1', 'B3LYP', 'PBE0', 'BHLYP', 'TPSSH']
error_recp.loc[mCmpds,Mfunc].style.applymap(enthal_color_quan)
# Out:
# <style  type="text/css" >
#     #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col0 {
#             color:  firebrick;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col1 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col2 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col3 {
#             color:  chocolate;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col4 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col5 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col6 {
#             color:  chocolate;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col7 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col8 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col9 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col10 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col11 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col12 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row0_col13 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col0 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col1 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col2 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col3 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col4 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col5 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col6 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col7 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col8 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col9 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col10 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col11 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col12 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row1_col13 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col0 {
#             color:  firebrick;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col1 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col2 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col3 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col4 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col5 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col6 {
#             color:  olive;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col7 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col8 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col9 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col10 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col11 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col12 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row2_col13 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col0 {
#             color:  chocolate;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col1 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col2 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col3 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col4 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col5 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col6 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col7 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col8 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col9 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col10 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col11 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col12 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row3_col13 {
#             color:  steelblue;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col0 {
#             color:  firebrick;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col1 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col2 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col3 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col4 {
#             color:  darkgoldenrod;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col5 {
#             color:  chocolate;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col6 {
#             color:  chocolate;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col7 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col8 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col9 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col10 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col11 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col12 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row4_col13 {
#             color:  orangered;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col0 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col1 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col2 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col3 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col4 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col5 {
#             color:  firebrick;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col6 {
#             color:  chocolate;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col7 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col8 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col9 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col10 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col11 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col12 {
#             color:  crimson;
#         }    #T_dbe71e54_93dd_11e7_80b6_00059a3c7a00row5_col13 {

# %%
error_so.loc[mCmpds,Mfunc].style.applymap(enthal_color_quan)
# Out:
# <style  type="text/css" >
#     #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col0 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col1 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col2 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col3 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col4 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col5 {
#             color:  olive;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col6 {
#             color:  firebrick;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col7 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col8 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col9 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col10 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col11 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col12 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row0_col13 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col0 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col1 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col2 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col3 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col4 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col5 {
#             color:  steelblue;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col6 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col7 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col8 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col9 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col10 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col11 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col12 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row1_col13 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col0 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col1 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col2 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col3 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col4 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col5 {
#             color:  olive;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col6 {
#             color:  olive;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col7 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col8 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col9 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col10 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col11 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col12 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row2_col13 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col0 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col1 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col2 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col3 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col4 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col5 {
#             color:  steelblue;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col6 {
#             color:  olive;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col7 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col8 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col9 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col10 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col11 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col12 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row3_col13 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col0 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col1 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col2 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col3 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col4 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col5 {
#             color:  chocolate;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col6 {
#             color:  chocolate;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col7 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col8 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col9 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col10 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col11 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col12 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row4_col13 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col0 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col1 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col2 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col3 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col4 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col5 {
#             color:  firebrick;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col6 {
#             color:  chocolate;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col7 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col8 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col9 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col10 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col11 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col12 {
#             color:  k;
#         }    #T_ded8e690_93dd_11e7_9af5_00059a3c7a00row5_col13 {
#             color:  k;
#         }</style>
# <table id="T_ded8e690_93dd_11e7_9af5_00059a3c7a00" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >SVWN</th>
#         <th class="col_heading level0 col1" >BP86</th>
#         <th class="col_heading level0 col2" >BLYP</th>
#         <th class="col_heading level0 col3" >PW91</th>
#         <th class="col_heading level0 col4" >PBE</th>
#         <th class="col_heading level0 col5" >TPSS</th>
#         <th class="col_heading level0 col6" >M06-L</th>
#         <th class="col_heading level0 col7" >B3P86</th>

# %% [markdown]
# ### Uncomment block below to print to LaTeX output

# %%
# tex_file = open('5d_differences.tex','w')
# print(first_half.round(2).to_latex(),file=tex_file)
# print(second_half.round(2).to_latex(),file=tex_file)
# tex_file.close()
# print(error_recp.T.round(2).to_latex())
# print(error_so.loc[mCmpds,Mfunc].T.round(2).to_latex())
